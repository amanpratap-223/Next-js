# %% [markdown]
# <a href="https://colab.research.google.com/github/amanpratap-223/Next-js/blob/main/IMAGE_RECOGNITION_ON_CIFAR_10_DATASET_USING_CONVOLUTIONAL_NEURAL_NETWORK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IMAGE RECOGNITION ON CIFAR-10 DATASET USING CNN

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense,BatchNormalization,GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import cifar10
from sklearn.model_selection import train_test_split
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## 1.Loading and preparing the data

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
x_train , x_val ,y_train,y_val = train_test_split(x_train , y_train , test_size = 0.2 , random_state = 42)

# %% [markdown]
# #### Example of the data set

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']
plt.figure(figsize = (5,5))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(x_train[i])
    # plt.title(class_names[int(y_train[i])])
    plt.title(class_names[y_train[i].item()])
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
print('Shape of x_train',x_train.shape)
print('data type of x_train',x_train.dtype)
print('Number of dimensions of x_train',x_train.ndim)
# Out:
# Shape of x_train (40000, 32, 32, 3)
# data type of x_train float64
# Number of dimensions of x_train 4

# %%
print(y_train.shape)
# Out:
# (40000, 1)

# %%
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)
y_val = to_categorical(y_val, 10)

# %%
model1 = Sequential([
    #1st layer
    Conv2D(32,(3,3),activation = 'relu',input_shape = (32,32,3)),
    MaxPooling2D(pool_size = (2,2)),
    Dropout(0.2),

    #Second Layer
    Conv2D(64,(3,3),activation = 'relu'),
    MaxPooling2D(pool_size = (2,2)),
    Dropout(0.2),



    Flatten(),


    Dense(128,activation = 'relu'),
    Dropout(0.40),
    Dense(10,activation = 'softmax')



])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2304)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 315,722 (1.20 MB)
#  Trainable params: 315,722 (1.20 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model1.compile(optimizer = 'adam' , loss = 'categorical_crossentropy',metrics = ['accuracy'])

# %%
history = model1.fit(
    x_train,
    y_train,
    epochs = 20,
    verbose = 1,
    validation_data = (x_val,y_val)

)
# Out:
# Epoch 1/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.3020 - loss: 1.8791 - val_accuracy: 0.5016 - val_loss: 1.4157
# Epoch 2/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 5ms/step - accuracy: 0.4899 - loss: 1.4101 - val_accuracy: 0.5761 - val_loss: 1.2035
# Epoch 3/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.5525 - loss: 1.2583 - val_accuracy: 0.6198 - val_loss: 1.0966
# Epoch 4/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5871 - loss: 1.1682 - val_accuracy: 0.6435 - val_loss: 1.0415
# Epoch 5/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.6061 - loss: 1.1146 - val_accuracy: 0.6568 - val_loss: 0.9862
# Epoch 6/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6236 - loss: 1.0636 - val_accuracy: 0.6519 - val_loss: 0.9927
# Epoch 7/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6369 - loss: 1.0185 - val_accuracy: 0.6696 - val_loss: 0.9512
# Epoch 8/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.6542 - loss: 0.9893 - val_accuracy: 0.6815 - val_loss: 0.9278
# Epoch 9/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6657 - loss: 0.9457 - val_accuracy: 0.6911 - val_loss: 0.8980
# Epoch 10/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6698 - loss: 0.9353 - val_accuracy: 0.6886 - val_loss: 0.8957
# Epoch 11/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6761 - loss: 0.9148 - val_accuracy: 0.6994 - val_loss: 0.8617
# Epoch 12/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.6809 - loss: 0.8961 - val_accuracy: 0.6905 - val_loss: 0.8774
# Epoch 13/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6905 - loss: 0.8731 - val_accuracy: 0.7018 - val_loss: 0.8633
# Epoch 14/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6970 - loss: 0.8532 - val_accuracy: 0.7003 - val_loss: 0.8597
# Epoch 15/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.6993 - loss: 0.8439 - val_accuracy: 0.7042 - val_loss: 0.8589
# Epoch 16/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7045 - loss: 0.8317 - val_accuracy: 0.7113 - val_loss: 0.8468
# Epoch 17/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.7107 - loss: 0.8092 - val_accuracy: 0.7118 - val_loss: 0.8320
# Epoch 18/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7114 - loss: 0.8041 - val_accuracy: 0.7149 - val_loss: 0.8311
# Epoch 19/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7160 - loss: 0.7906 - val_accuracy: 0.7070 - val_loss: 0.8540
# Epoch 20/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7211 - loss: 0.7804 - val_accuracy: 0.7019 - val_loss: 0.8706

# %%
test_loss , test_accuracy = model1.evaluate(
    x_test,
    y_test,
    verbose = 1

)

print(f'\nTest Accuracy: {test_accuracy:.4f}')
print(f'Test Loss: {test_loss:.4f}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7066 - loss: 0.8645
#
# Test Accuracy: 0.7021
# Test Loss: 0.8801

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

y_pred_prob = model1.predict(x_test)
y_pred = np.argmax(y_pred_prob,axis=1)
import seaborn as sns

y_pred_prob = model1.predict(x_test)
y_pred = np.argmax(y_pred_prob,axis=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
y_true = np.argmax(y_test, axis=1)

# %% [markdown]
# ### Confusion Matrix

# %%
cm = confusion_matrix(y_true, y_pred)

# %%
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
print("Classification Report:")
print(classification_report(y_true, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.79      0.73      1000
#            1       0.81      0.82      0.81      1000
#            2       0.60      0.60      0.60      1000
#            3       0.56      0.46      0.51      1000
#            4       0.64      0.64      0.64      1000
#            5       0.65      0.57      0.61      1000
#            6       0.71      0.83      0.77      1000
#            7       0.79      0.73      0.76      1000
#            8       0.71      0.88      0.78      1000
#            9       0.85      0.71      0.77      1000
#
#     accuracy                           0.70     10000
#    macro avg       0.70      0.70      0.70     10000
# weighted avg       0.70      0.70      0.70     10000

# %%
plt.figure(figsize=(12, 5))

# %%
# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# Class names for CIFAR-10
class_names = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer',
               'Dog', 'Frog', 'Horse', 'Ship', 'Truck']

# Select a random image from the test set
random_index = random.randint(0, len(x_test) - 1)
random_image = x_test[random_index]

# Get the true label index (since y_test is one-hot encoded)
true_label = class_names[np.argmax(y_test[random_index])]

# Predict the class
prediction = model1.predict(np.expand_dims(random_image, axis=0))
predicted_class = class_names[np.argmax(prediction)]

# Plot the image with prediction results
plt.imshow(random_image)
plt.title(f"True: {true_label} | Predicted: {predicted_class}")
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step

# %%
model2 = Sequential([
    # 1st Convolutional Block
    Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.2),

    # 2nd Convolutional Block
    Conv2D(64, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.3),

    # 3rd Convolutional Block
    Conv2D(128, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.4),

    # Global Average Pooling instead of Flatten
    GlobalAveragePooling2D(),

    # Fully Connected Layer
    Dense(128, activation='relu'),
    Dropout(0.3),

    Dense(64,activation = 'relu'),
    Dropout(0.2),
    # Output Layer
    Dense(10, activation='softmax')

])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 119,562 (467.04 KB)
#  Trainable params: 119,114 (465.29 KB)
#  Non-trainable params: 448 (1.75 KB)

# %%
model2.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %% [markdown]
# DATA AUGMENTATION FOR INCREASING THE DATASET

# %%
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.2,
    shear_range=0.1,
    brightness_range=[0.8, 1.2]
)

datagen.fit(x_train)

# %%
# Reduce LR on plateau
lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    verbose=1
)

# %%
# Early stopping
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True,
    verbose=1
)

# %%
history2 = model2.fit(
    x = x_train,
    y = y_train,
    validation_data=(x_val, y_val),
    epochs= 40,
    callbacks = [early_stop,lr_scheduler]

)
# Out:
# Epoch 1/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - accuracy: 0.3026 - loss: 1.8775 - val_accuracy: 0.4698 - val_loss: 1.4607 - learning_rate: 0.0010
# Epoch 2/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4771 - loss: 1.4258 - val_accuracy: 0.5023 - val_loss: 1.3710 - learning_rate: 0.0010
# Epoch 3/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.5439 - loss: 1.2734 - val_accuracy: 0.3840 - val_loss: 1.9134 - learning_rate: 0.0010
# Epoch 4/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.5719 - loss: 1.1986 - val_accuracy: 0.6075 - val_loss: 1.0703 - learning_rate: 0.0010
# Epoch 5/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.6060 - loss: 1.1256 - val_accuracy: 0.6162 - val_loss: 1.0626 - learning_rate: 0.0010
# Epoch 6/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.6173 - loss: 1.0820 - val_accuracy: 0.6093 - val_loss: 1.0581 - learning_rate: 0.0010
# Epoch 7/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.6256 - loss: 1.0550 - val_accuracy: 0.6489 - val_loss: 0.9864 - learning_rate: 0.0010
# Epoch 8/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.6413 - loss: 1.0266 - val_accuracy: 0.6131 - val_loss: 1.0756 - learning_rate: 0.0010
# Epoch 9/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6506 - loss: 1.0057 - val_accuracy: 0.6547 - val_loss: 0.9618 - learning_rate: 0.0010
# Epoch 10/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.6576 - loss: 0.9792 - val_accuracy: 0.6966 - val_loss: 0.8570 - learning_rate: 0.0010
# Epoch 11/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.6700 - loss: 0.9496 - val_accuracy: 0.6840 - val_loss: 0.8723 - learning_rate: 0.0010
# Epoch 12/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6705 - loss: 0.9440 - val_accuracy: 0.6613 - val_loss: 0.9547 - learning_rate: 0.0010
# Epoch 13/40
# 1243/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6751 - loss: 0.9342
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.6751 - loss: 0.9343 - val_accuracy: 0.6996 - val_loss: 0.8574 - learning_rate: 0.0010
# Epoch 14/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.6926 - loss: 0.8880 - val_accuracy: 0.7274 - val_loss: 0.7851 - learning_rate: 5.0000e-04
# Epoch 15/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.7016 - loss: 0.8543 - val_accuracy: 0.7313 - val_loss: 0.7460 - learning_rate: 5.0000e-04
# Epoch 16/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.6979 - loss: 0.8574 - val_accuracy: 0.6679 - val_loss: 0.9450 - learning_rate: 5.0000e-04
# Epoch 17/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.7111 - loss: 0.8357 - val_accuracy: 0.7294 - val_loss: 0.7460 - learning_rate: 5.0000e-04
# Epoch 18/40
# 1249/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7153 - loss: 0.8249
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7153 - loss: 0.8249 - val_accuracy: 0.6686 - val_loss: 0.9272 - learning_rate: 5.0000e-04
# Epoch 19/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7139 - loss: 0.8165 - val_accuracy: 0.7416 - val_loss: 0.7269 - learning_rate: 2.5000e-04
# Epoch 20/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.7214 - loss: 0.8065 - val_accuracy: 0.7427 - val_loss: 0.7187 - learning_rate: 2.5000e-04
# Epoch 21/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7201 - loss: 0.7954 - val_accuracy: 0.7523 - val_loss: 0.7043 - learning_rate: 2.5000e-04
# Epoch 22/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.7277 - loss: 0.7823 - val_accuracy: 0.7646 - val_loss: 0.6642 - learning_rate: 2.5000e-04
# Epoch 23/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7310 - loss: 0.7823 - val_accuracy: 0.7633 - val_loss: 0.6757 - learning_rate: 2.5000e-04
# Epoch 24/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7302 - loss: 0.7760 - val_accuracy: 0.7523 - val_loss: 0.7108 - learning_rate: 2.5000e-04
# Epoch 25/40
# 1248/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7338 - loss: 0.7688
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.7338 - loss: 0.7688 - val_accuracy: 0.7426 - val_loss: 0.7244 - learning_rate: 2.5000e-04
# Epoch 26/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.7298 - loss: 0.7693 - val_accuracy: 0.7520 - val_loss: 0.6972 - learning_rate: 1.2500e-04
# Epoch 27/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.7345 - loss: 0.7626 - val_accuracy: 0.7652 - val_loss: 0.6549 - learning_rate: 1.2500e-04
# Epoch 28/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7352 - loss: 0.7565 - val_accuracy: 0.7674 - val_loss: 0.6567 - learning_rate: 1.2500e-04
# Epoch 29/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.7373 - loss: 0.7538 - val_accuracy: 0.7618 - val_loss: 0.6697 - learning_rate: 1.2500e-04
# Epoch 30/40
# 1237/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7449 - loss: 0.7443
# Epoch 30: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7449 - loss: 0.7443 - val_accuracy: 0.7640 - val_loss: 0.6627 - learning_rate: 1.2500e-04
# Epoch 31/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7385 - loss: 0.7487 - val_accuracy: 0.7737 - val_loss: 0.6372 - learning_rate: 6.2500e-05
# Epoch 32/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.7416 - loss: 0.7413 - val_accuracy: 0.7645 - val_loss: 0.6644 - learning_rate: 6.2500e-05
# Epoch 33/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.7418 - loss: 0.7375 - val_accuracy: 0.7733 - val_loss: 0.6383 - learning_rate: 6.2500e-05
# Epoch 34/40
# 1248/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7427 - loss: 0.7402
# Epoch 34: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.7427 - loss: 0.7402 - val_accuracy: 0.7665 - val_loss: 0.6565 - learning_rate: 6.2500e-05
# Epoch 35/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7498 - loss: 0.7252 - val_accuracy: 0.7619 - val_loss: 0.6717 - learning_rate: 3.1250e-05
# Epoch 36/40
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.7413 - loss: 0.7457 - val_accuracy: 0.7743 - val_loss: 0.6376 - learning_rate: 3.1250e-05
# Epoch 36: early stopping
# Restoring model weights from the end of the best epoch: 31.

# %%
test_loss , test_accuracy = model2.evaluate(
    x_test,
    y_test,
    verbose = 1

)

print(f'\nTest Accuracy: {test_accuracy:.4f}')
print(f'Test Loss: {test_loss:.4f}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7728 - loss: 0.6430
#
# Test Accuracy: 0.7709
# Test Loss: 0.6511

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# %%
y2_pred_prob = model2.predict(x_test)
y2_pred = np.argmax(y2_pred_prob,axis=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step

# %%
y2_true = np.argmax(y_test, axis=1)

# %%
cm2 = confusion_matrix(y2_true, y2_pred)

# %%
plt.figure(figsize=(8,6))
sns.heatmap(cm2, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
print("Classification Report:")
print(classification_report(y2_true, y2_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.79      0.79      1000
#            1       0.91      0.90      0.91      1000
#            2       0.78      0.55      0.64      1000
#            3       0.67      0.50      0.58      1000
#            4       0.66      0.79      0.72      1000
#            5       0.65      0.74      0.69      1000
#            6       0.72      0.88      0.79      1000
#            7       0.85      0.77      0.81      1000
#            8       0.83      0.92      0.87      1000
#            9       0.89      0.86      0.88      1000
#
#     accuracy                           0.77     10000
#    macro avg       0.77      0.77      0.77     10000
# weighted avg       0.77      0.77      0.77     10000

# %%
plt.figure(figsize=(12, 5))

# %%
# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history2.history['accuracy'], label='Training Accuracy')
plt.plot(history2.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history2.history['loss'], label='Training Loss')
plt.plot(history2.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# Class names for CIFAR-10
class_names = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer',
               'Dog', 'Frog', 'Horse', 'Ship', 'Truck']

# Select a random image from the test set
random_index = random.randint(0, len(x_test) - 1)
random_image = x_test[random_index]

# Get the true label index (since y_test is one-hot encoded)
true_label = class_names[np.argmax(y_test[random_index])]

# Predict the class
prediction = model2.predict(np.expand_dims(random_image, axis=0))
predicted_class = class_names[np.argmax(prediction)]


# Plot the image with prediction results
plt.imshow(random_image)
plt.title(f"True: {true_label} | Predicted: {predicted_class}")
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
